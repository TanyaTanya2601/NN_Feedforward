# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
class multilayer():
    inputlayer= 1
    hiddenlayer= 1
    outputlayer= 1
    
    X1= 0.35
    X2= 0.9
    W31= 0.1
    W41= 0.4
    W32= 0.8
    W42= 0.6
    
    H3= X1*W31+X2*W32
    H4= X1*W41+X2*W42
    print("H3 = ", H3)
    print("H4 =" ,H4)
    
    W53= 0.3
    W54= 0.9
    
    output= H3*W53+H4*W54
    print(output)
# Out:
# H3 =  0.7550000000000001
# H4 = 0.68
# 0.8385000000000001
